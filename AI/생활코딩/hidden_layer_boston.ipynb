# %%
#라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 1. 보스턴 집값 예측 데이터
path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
boston = pd.read_csv(path)

#종속, 독립 분리
독립 = boston[['crim', 'zn', 'indus', 'chas', 'nox', 
            'rm', 'age', 'dis', 'rad', 'tax',
            'ptratio', 'b', 'lstat']]
종속 = boston[['medv']]
print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
# 2. 모델의 구조

X = tf.keras.layers.Input(shape = [13])
#hidden layer를 추가하여 multi layer로 변경
H = tf.keras.layers.Dense(10, activation = 'swish') (X)
Y = tf.keras.layers.Dense(1) (H)

model = tf.keras.models.Model(X, Y)
model.compile(loss = 'mse')

# %%
model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 13)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                140
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 3. 데이터로 모델 학습(fit)
model.fit(독립, 종속, epochs=1000, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 25.4278
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.0395
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.8390
# Epoch 4/10
# 16/16 [==============================] - 0s 998us/step - loss: 21.2805
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.4741
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.4804
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 24.5843
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 21.5924
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.6395
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 23.8659

# %%
# 4. 모델 이용
print(model.predict(독립[:5]))
print(종속[:5])
# Out:
# [[31.137896]
#  [25.718815]
#  [31.71064 ]
#  [32.548542]
#  [31.880913]]
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2
