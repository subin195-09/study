# %%
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 1. 과거의 데이터 준비
path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
iris = pd.read_csv(path)

# one-hot encoding
iris = pd.get_dummies(iris)

# %%
# 독립, 종속 분리
독립 = iris[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
종속 = iris[['품종_setosa', '품종_versicolor', '품종_virginica']]

print(독립.shape, 종속.shape)
# Out:
# (150, 4) (150, 3)

# %%
# 2. 모델 구조 만들기

X = tf.keras.layers.Input(shape = [4])

H = tf.keras.layers.Dense(8) (X)
H = tf.keras.layers.BatchNormalization() (H)
H = tf.keras.layers.Activation('swish') (H)

H = tf.keras.layers.Dense(8) (H)
H = tf.keras.layers.BatchNormalization() (H)
H = tf.keras.layers.Activation('swish') (H)

H = tf.keras.layers.Dense(8) (H)
H = tf.keras.layers.BatchNormalization() (H)
H = tf.keras.layers.Activation('swish') (H)

Y = tf.keras.layers.Dense(3, activation='softmax') (H)

model = tf.keras.models.Model(X, Y)
model.compile(loss = 'categorical_crossentropy', metrics = 'accuracy')

# %%
# 3. 모델 학습(fit)
model.fit(독립, 종속, epochs=1000, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0518 - accuracy: 0.9667
# Epoch 2/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9867
# Epoch 3/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0399 - accuracy: 0.9800
# Epoch 4/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 5/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9933
# Epoch 6/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9933
# Epoch 7/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 0.9867
# Epoch 8/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9867
# Epoch 9/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1647 - accuracy: 0.9667
# Epoch 10/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0150 - accuracy: 1.0000

# %%
####################################################################################################################
# 기존 모델과 비교

# 1. 과거의 데이터 준비
path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
iris = pd.read_csv(path)

# one-hot encoding
iris = pd.get_dummies(iris)

# 독립, 종속 분리
독립 = iris[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
종속 = iris[['품종_setosa', '품종_versicolor', '품종_virginica']]

# 2. 모델의 구조를 만들기
X = tf.keras.layers.Input(shape=[4])
H = tf.keras.layers.Dense(8, activation='swish')(X)
H = tf.keras.layers.Dense(8, activation='swish')(H)
H = tf.keras.layers.Dense(8, activation='swish')(H)
Y = tf.keras.layers.Dense(3, activation='softmax')(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='categorical_crossentropy',
              metrics='accuracy')

# 3. 모델 학습(fit)
model.fit(독립, 종속, epochs=1000, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 0.9867
# Epoch 2/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9867
# Epoch 3/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 0.9800
# Epoch 4/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0435 - accuracy: 0.9867
# Epoch 5/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0505 - accuracy: 0.9800
# Epoch 6/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0615 - accuracy: 0.9733
# Epoch 7/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 0.9800
# Epoch 8/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0499 - accuracy: 0.9667
# Epoch 9/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 0.9867
# Epoch 10/10
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0498 - accuracy: 0.9867
