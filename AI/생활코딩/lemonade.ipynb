# %%
#라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
#데이터 준비
path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/lemonade.csv'
lemonade = pd.read_csv(path)

#데이터 확인
lemonade.head()
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48

# %%
#종속, 독립 변수 분리
독립 = lemonade[['온도']]
종속 = lemonade[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
#모델 만들기

#독립변수 컬럼 수 : shape
X = tf.keras.layers.Input(shape = [1])

#종속변수 컬럼 수  : Dense
Y = tf.keras.layers.Dense(1) (X)

model = tf.keras.models.Model(X, Y)

#'mse'는 학습 방식
model.compile(loss = 'mse')

# %%
#모델 학습
#verbose = 0 : 출력을 시키지 않겠다는 의미
model.fit(독립, 종속, epochs = 10000, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5252e-04
# Epoch 2/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5251e-04
# Epoch 3/10
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5247e-04
# Epoch 4/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5237e-04
# Epoch 5/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5222e-04
# Epoch 6/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5217e-04
# Epoch 7/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5220e-04
# Epoch 8/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5224e-04
# Epoch 9/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5228e-04
# Epoch 10/10
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5229e-04

# %%
#학습된 모델을 이용해 예측한다
print(model.predict(독립))
print(종속)
print(model.predict(([15])))
# Out:
# [[39.99513 ]
#  [41.992485]
#  [43.98984 ]
#  [45.987198]
#  [47.98455 ]
#  [49.981907]]
#    판매량
# 0   40
# 1   42
# 2   44
# 3   46
# 4   48
# 5   50
# [[30.008347]]
