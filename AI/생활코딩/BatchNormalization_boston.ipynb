# %%
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 1. 과거의 데이터 준비
path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
boston = pd.read_csv(path)

# %%
# 독립, 종속 분리
독립 = boston[['crim', 'zn', 'indus', 'chas', 'nox', 
            'rm', 'age', 'dis', 'rad', 'tax',
            'ptratio', 'b', 'lstat']]
종속 = boston[['medv']]
print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
# 2. 모델 구조 만들기
X = tf.keras.layers.Input(shape = [13])

# Dense와 activation 사이에 Batch가 있어야 효율적이기 때문에
# 분리시켜서 구조를 만든다.
H = tf.keras.layers.Dense(8)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

H = tf.keras.layers.Dense(8)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

Y = tf.keras.layers.Dense(1)(H)

model = tf.keras.models.Model(X, Y)
model.compile(loss = 'mse')

# %%
# 3. 모델 학습(fit)
model.fit(독립, 종속, epochs = 1000, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 11.6403
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 11.0704
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 12.1923
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 9.8188
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 12.0857
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 11.4084
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 11.0475
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 10.8231
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 12.7817
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 12.9002

# %%
# 4. 모델 이용
print(model.predict(독립[:5]))
print(종속[:5])
# Out:
# [[22.407898]
#  [20.126085]
#  [28.200052]
#  [26.554718]
#  [26.951017]]
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
####################################################################################################################
# 기존 학습 방식과 비교

# 1. 과거의 데이터 준비
path = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
boston = pd.read_csv(path)
 
# 종속변수, 독립변수
독립 = boston[['crim', 'zn', 'indus', 'chas', 'nox', 
            'rm', 'age', 'dis', 'rad', 'tax',
            'ptratio', 'b', 'lstat']]
종속 = boston[['medv']]
print(독립.shape, 종속.shape)
 
###########################
# 2. 모델의 구조를 만듭니다
X = tf.keras.layers.Input(shape=[13])

H = tf.keras.layers.Dense(8, activation='swish')(X)
H = tf.keras.layers.Dense(8, activation='swish')(X)
H = tf.keras.layers.Dense(8, activation='swish')(X)

Y = tf.keras.layers.Dense(1)(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

###########################
# 3.데이터로 모델을 학습(FIT)합니다.
model.fit(독립, 종속, epochs = 1000, verbose=0)
model.fit(독립, 종속, epochs=10)
 
###########################
# 4. 모델을 이용합니다
print(model.predict(독립[:5]))
print(종속[:5])
# Out:
# (506, 13) (506, 1)
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 15.1648
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 15.2982
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 15.2695
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 14.9755
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 15.4909
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 15.3768
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 15.7222
# Epoch 8/10
# 16/16 [==============================] - 0s 985us/step - loss: 15.8313
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 15.0112
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 15.2553
# [[32.420612]
#  [21.299116]
#  [30.811678]
#  [33.204365]
#  [28.774244]]
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2
